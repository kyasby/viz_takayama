# %%
import pandas as pd
import json

# %%
df = pd.read_json("/Users/ryo/Documents/rec.json", lines=True)

# %%
df.iloc[-1]["counterHistory"]
# Out:
#                                         _id  \
# 0      {'$oid': '60b8a307dcf84e0062d79f5c'}
# 1      {'$oid': '60b8bbbfdcf84e0062d94147'}
# 2      {'$oid': '60b8bbfbdcf84e0062d94560'}
# 3      {'$oid': '60b8bc37dcf84e0062d9497d'}
# 4      {'$oid': '60b8bc73dcf84e0062d94d98'}
# ...                                     ...
# 48280  {'$oid': '618e10f621ddc60060311c04'}
# 48281  {'$oid': '618e1f0721ddc60060321f67'}
# 48282  {'$oid': '618e2d1621ddc6006033170c'}
# 48283  {'$oid': '618e3b2721ddc60060340e33'}
# 48284  {'$oid': '618e493621ddc6006035022c'}
#
#                                    dateStart  \
# 0       {'$date': '2021-06-03T09:38:15.65Z'}
# 1      {'$date': '2021-06-03T11:23:43.204Z'}
# 2      {'$date': '2021-06-03T11:24:43.373Z'}
# 3      {'$date': '2021-06-03T11:25:43.541Z'}
# 4      {'$date': '2021-06-03T11:26:43.696Z'}
# ...                                      ...
# 48280  {'$date': '2021-11-12T07:00:06.663Z'}
# 48281   {'$date': '2021-11-12T08:00:07.05Z'}
# ...
